# %% [markdown]
# 作業1:
# 資料集名稱：U.S. Education Datasets: Unification Project
# 資料集網址：https://www.kaggle.com/noriuk/us-education-datasets-unification-project
#
# 1. 你選的這組資料為何重要
# 彙整美國各級教育的資料，有助於了解美國目前的教育趨勢
#
# 2. 資料從何而來
# U.S. Census Bureau and the National Center for Education Statistics (NCES).
#
# 3. 蒐集而來的資料型態為何
# 很多零散的csv檔
#
# 4. 這組資料想解決的問題如何評估
# 這資料主要著重在教育相關的資料蒐集，不僅包含各州學童的教育程度(數學考試)以及經濟狀況。
# 不過資料集本身的介紹並無提到旨在解決什麼問題？若是最基礎的教育程度與經濟狀況的相關性，或許可以使用迴歸分析。

# %%
作業2：
想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：

1. 核心問題為何？
整體的核心業績，主要著重要在效率(錢/里程)

2. 資料從何而來？
相關資料為人流或運量？人流不確定要如何統計，不過各大交通站點的運量應該可從市府的官網得知。

3. 蒐集而來的資料型態為何？
主要為數值化的資料，少數描述性的資料。

4. 你要回答的問題，其如何評估？
常經過流量(人流or運量)點高的車子是否效率(錢/里程)高。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(label, pred):
    # label and pred are 1D numpy
    num_sample = label.shape[0]
    mse = ((label - pred) ** 2).sum(axis = 0) / num_sample
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 201.673
